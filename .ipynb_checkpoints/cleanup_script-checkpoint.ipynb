# %% [markdown]
# ## Test JSON Conversion to CSV Process

# %%
# Import modules
import os
import pandas as pd
import json

# %%
# Load JSON

# Set path where JSON is located
json_file_path = os.path.join("Data", "CA_category_id.json")

# Open and load JSON
with open(json_file_path, "r") as json_file:
    data = json.load(json_file)
data

# %%
# Eliminate main metadata/create iterable list of documents
item = data['items']
item

# %%
# Create empty lists to hold relevant data in JSON
id = []
channelID = []
title = []
assign = []

# Append data from each document to relevant list
for doc in item:
    id.append(doc['id'])
    channelID.append(doc['snippet']['channelId'])
    title.append(doc['snippet']['title'])
    assign.append(doc['snippet']['assignable'])

# %%
# Zip lists to create dataframe
df = pd.DataFrame(list(zip(id, channelID, title, assign)),
                 columns = ['Number', 'Channel ID', 'Title', 'Assignable?'])
df

# %%
# Test df export to CSV
country_code = "CA"

output_file_path = os.path.join("Data", f'{country_code}_category_id.csv')

df.to_csv(output_file_path, index=False)

# %% [markdown]
# ## Convert All JSONs to CSVs

# %% [markdown]
# ### Create Function

# %%
# Create function to convert all JSON files to CSV
def json_conversion(code):
    json_file_path = os.path.join("Data", f'{code}_category_id.json')
    with open(json_file_path, "r") as json_file:
        data = json.load(json_file)
    item = data['items']
    country = []
    id = []
    channelID = []
    title = []
    assign = []
    for doc in item:
        country.append(code)
        id.append(doc['id'])
        channelID.append(doc['snippet']['channelId'])
        title.append(doc['snippet']['title'])
        assign.append(doc['snippet']['assignable'])
    df = pd.DataFrame(list(zip(country, id, channelID, title, assign)),
                 columns = ['country', 'id_number', 'channel_id', 'title', 'assignable'])
    output_file_path = os.path.join("Data", f'{code}_category_id.csv')
    df.to_csv(output_file_path, index=False)

# %% [markdown]
# ### Call Function to Convert JSONs

# %%
# Create list of data file country codes
countries = ["CA", "DE", "FR", "GB", "IN", "JP", "KR", "MX", "RU", "US"]

for code in countries:
    json_conversion(code)

# %% [markdown]
# ## Prepare Video CSV Files

# %% [markdown]
# ### Create video_countries Files

# %%
countries = ["CA", "DE", "FR", "GB", "IN", "JP", "KR", "MX", "RU", "US"]
d = {}

for code in countries:
    video_file_path = os.path.join("Data", f'{code}videos.csv')
    new_df = pd.read_csv(video_file_path, encoding ='utf_8')
    clean_df = new_df.loc[:, ['video_id', 'title', 'views', 'comment_count', 'trending_date']].copy()
    for row in clean_df:
        clean_df['country_code'] = code
    output_path = os.path.join("Data", f'{code}videos_clean.csv')
    clean_df.to_csv(output_path, index=False)
    d['df' + str(code)] = clean_df.add_suffix('_' + str(code))

d
        
video_countries_df = pd.concat([d['dfCA'], d['dfDE'], d['dfFR'], d['dfGB'], d['dfIN'], d['dfJP'], d['dfKR'], d['dfMX'], d['dfRU'], d['dfUS']])
video_countries_df
# Out:
#        video_id_CA                                           title_CA  \
# 0      n1WpP7iowLc         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      0dBIkQ4Mz1M                      PLUSH - Bad Unboxing Fan Mail
# 2      5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      d380meD0W0M                           I Dare You: GOING BALD!?
# 4      2Vv-BfVoq4g        Ed Sheeran - Perfect (Official Music Video)
# ...            ...                                                ...
# 40944          NaN                                                NaN
# 40945          NaN                                                NaN
# 40946          NaN                                                NaN
# 40947          NaN                                                NaN
# 40948          NaN                                                NaN
#
#          views_CA  comment_count_CA trending_date_CA country_code_CA  \
# 0      17158579.0          125882.0         17.14.11              CA
# 1       1014651.0           13030.0         17.14.11              CA
# 2       3191434.0            8181.0         17.14.11              CA
# 3       2095828.0           17518.0         17.14.11              CA
# 4      33523622.0           85067.0         17.14.11              CA
# ...           ...               ...              ...             ...
# 40944         NaN               NaN              NaN             NaN
# 40945         NaN               NaN              NaN             NaN
# 40946         NaN               NaN              NaN             NaN
# 40947         NaN               NaN              NaN             NaN
# 40948         NaN               NaN              NaN             NaN
#
#       video_id_DE title_DE  views_DE  comment_count_DE  ... views_RU  \
# 0             NaN      NaN       NaN               NaN  ...      NaN
# 1             NaN      NaN       NaN               NaN  ...      NaN
# 2             NaN      NaN       NaN               NaN  ...      NaN
# 3             NaN      NaN       NaN               NaN  ...      NaN
# 4             NaN      NaN       NaN               NaN  ...      NaN
# ...           ...      ...       ...               ...  ...      ...
# 40944         NaN      NaN       NaN               NaN  ...      NaN
# 40945         NaN      NaN       NaN               NaN  ...      NaN
# 40946         NaN      NaN       NaN               NaN  ...      NaN
# 40947         NaN      NaN       NaN               NaN  ...      NaN
# 40948         NaN      NaN       NaN               NaN  ...      NaN
#
#       comment_count_RU trending_date_RU country_code_RU  video_id_US  \
# 0                  NaN              NaN             NaN          NaN
# 1                  NaN              NaN             NaN          NaN
# 2                  NaN              NaN             NaN          NaN
# 3                  NaN              NaN             NaN          NaN
# 4                  NaN              NaN             NaN          NaN
# ...                ...              ...             ...          ...
# 40944              NaN              NaN             NaN  BZt0qjTWNhw
# 40945              NaN              NaN             NaN  1h7KV2sjUWY
# 40946              NaN              NaN             NaN  D6Oy4LfoqsU
# 40947              NaN              NaN             NaN  oV0zkMe1K8s
# 40948              NaN              NaN             NaN  ooyjaVdt-jA
#
#                                                 title_US    views_US  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 40944                       The Cat Who Caught the Laser   1685609.0
# 40945                         True Facts : Ant Mutualism   1064798.0
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...   1066451.0
# 40947                How Black Panther Should Have Ended   5660813.0
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...  10306119.0
#
#       comment_count_US trending_date_US country_code_US
# 0                  NaN              NaN             NaN
# 1                  NaN              NaN             NaN
# 2                  NaN              NaN             NaN
# 3                  NaN              NaN             NaN
# 4                  NaN              NaN             NaN
# ...                ...              ...             ...
# 40944           2657.0         18.14.06              US
# 40945           3936.0         18.14.06              US
# 40946           3992.0         18.14.06              US
# 40947          13088.0         18.14.06              US
# 40948         144795.0         18.14.06              US
#
# [375942 rows x 60 columns]

# %%
d
# Out:
# {'dfCA':       video_id_tCA                                          title_tCA  \
#  0      n1WpP7iowLc         Eminem - Walk On Water (Audio) ft. Beyoncé
#  1      0dBIkQ4Mz1M                      PLUSH - Bad Unboxing Fan Mail
#  2      5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
#  3      d380meD0W0M                           I Dare You: GOING BALD!?
#  4      2Vv-BfVoq4g        Ed Sheeran - Perfect (Official Music Video)
#  ...            ...                                                ...
#  40876  sGolxsMSGfQ                       HOW2: How to Solve a Mystery
#  40877  8HNuRNi8t70                   Eli Lik Lik Episode 13 Partie 01
#  40878  GWlKEM3m2EE  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...
#  40879  lbMKLzQ4cNQ                   Trump Advisor Grovels To Trudeau
#  40880  POTgw38-m58                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班
#
#         views_tCA  comment_count_tCA trending_date_tCA country_code_tCA
#  0       17158579             125882          17.14.11               CA
#  1        1014651              13030          17.14.11               CA
#  2        3191434               8181          17.14.11               CA
#  3        2095828              17518          17.14.11               CA
#  4       33523622              85067          17.14.11               CA
#  ...          ...                ...               ...              ...
#  40876      80685               1312          18.14.06               CA
#  40877     103339                 51          18.14.06               CA
#  40878     773347               3881          18.14.06               CA
#  40879     115225               1672          18.14.06               CA
#  40880     107392                251          18.14.06               CA
#
#  [40881 rows x 6 columns],
#  'dfDE':       video_id_tDE                                          title_tDE  \
#  0      LgVi6y5QIjM  Sing zu Ende! | Gesangseinlagen vom Feinsten |...
#  1      Bayt7uQith4  Kinder ferngesteuert im Kiosk! Erwachsene abzo...
#  2      1ZAPwfrtAFY  The Trump Presidency: Last Week Tonight with J...
#  3      AHtypnRk7JE                                Das Fermi-Paradoxon
#  4      ZJ9We4bjcg0           18 SONGS mit Kelly MissesVlog (Sing-off)
#  ...            ...                                                ...
#  40835  fn5WNxy-Wcw  KINGDOM HEARTS III – E3 2018 Pirates of the Ca...
#  40836  zAFv43lxqHE                                     YMS: The Visit
#  40837  zSXG5I6Y2fA  Ungut umgeschult – Grünwald als Ersthelfer am ...
#  40838  5d115sePmaU  Assassin's Creed Odyssey: E3 2018 Welt-Enthüll...
#  40839  go-F6xvezAM  Гироскутер - Азбука Уральских Пельменей Б - Ур...
#
#         views_tDE  comment_count_tDE trending_date_tDE country_code_tDE
#  0         252786               1539          17.14.11               DE
#  1         797196               1278          17.14.11               DE
#  2        2418783              12703          17.14.11               DE
#  3         380247               1955          17.14.11               DE
#  4         822213              10244          17.14.11               DE
#  ...          ...                ...               ...              ...
#  40835    1394530               9878          18.14.06               DE
#  40836     139733               1968          18.14.06               DE
#  40837      26054                  8          18.14.06               DE
#  40838    1139198               1587          18.14.06               DE
#  40839     316328                550          18.14.06               DE
#
#  [40840 rows x 6 columns],
#  'dfFR':       video_id_tFR                                          title_tFR  \
#  0      Ro6eob0LrCY           Malika LePen : Femme de Gauche - Trailer
#  1      Yo84eqYwP98  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...
#  2      ceqntSXE-10  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...
#  3      WuTFI5qftCE                    PAPY GRENIER - METAL GEAR SOLID
#  4      ee6OFs8TdEg  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...
#  ...            ...                                                ...
#  40719  coVXf3Q9xBk  عاجل و رسمي : الملف الأمريكي يفوز بشرف تنظيم ك...
#  40720  _umkjOQJvtw  شاهد ملخص البرلمان اليوم بحضور اخنوش الدي يعطي...
#  40721  nt25ec7nzIM              UN ANIME EXPLOSIF A VOIR ABSOLUMENT !
#  40722  NlxE_QQMRzg  Նռան հատիկ, Սերիա 192 / Pomegranate seed / Nra...
#  40723  _LgKglfnqlc              Mandoumbé ak Koor Gui 2018 Episode 28
#
#         views_tFR  comment_count_tFR trending_date_tFR country_code_tFR
#  0         212702               3817          17.14.11               FR
#  1         432721               1161          17.14.11               FR
#  2         482153               9580          17.14.11               FR
#  3         925222               4303          17.14.11               FR
#  4         141695                481          17.14.11               FR
#  ...          ...                ...               ...              ...
#  40719      58758                485          18.14.06               FR
#  40720     264639               1397          18.14.06               FR
#  40721      47510                615          18.14.06               FR
#  40722      78117                 46          18.14.06               FR
#  40723      46604                127          18.14.06               FR
#
#  [40724 rows x 6 columns],
#  'dfGB':       video_id_tGB                                          title_tGB  \
#  0      Jw1Y-zhQURU      John Lewis Christmas Ad 2017 - #MozTheMonster
#  1      3s1rvMFUweQ          Taylor Swift: …Ready for It? (Live) - SNL
#  2      n1WpP7iowLc         Eminem - Walk On Water (Audio) ft. Beyoncé
#  3      PUTEiSjKwJU  Goals from Salford City vs Class of 92 and Fri...
#  4      rHwDegptbI4  Dashcam captures truck's near miss with child ...
#  ...            ...                                                ...
#  38911  l884wKofd54  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
#  38912  IP8k2xkhOdI  Jacob Sartorius - Up With It (Official Music V...
#  38913  Il-an3K9pjg                 Anne-Marie - 2002 [Official Video]
#  38914  -DRsfNObKIQ  Eleni Foureira - Fuego - Cyprus - LIVE - First...
#  38915  4YFo4bdMO8Q  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#         views_tGB  comment_count_tGB trending_date_tGB country_code_tGB
#  0        7224515               9479          17.14.11               GB
#  1        1053632               2757          17.14.11               GB
#  2       17158579             125882          17.14.11               GB
#  3          27833                 37          17.14.11               GB
#  4           9815                 30          17.14.11               GB
#  ...          ...                ...               ...              ...
#  38911   25066952               9933          18.14.06               GB
#  38912    1492219              24330          18.14.06               GB
#  38913   29641412              19988          18.14.06               GB
#  38914   14317515              26766          18.14.06               GB
#  38915     607552               1423          18.14.06               GB
#
#  [38916 rows x 6 columns],
#  'dfIN':       video_id_tIN                                          title_tIN  \
#  0      kzwfHumJyYc  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...
#  1      zUZ1z7FwLc8  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...
#  2      10L1hZ9qa58  Stylish Star Allu Arjun @ ChaySam Wedding Rece...
#  3      N1vE8iiEg64                     Eruma Saani | Tamil vs English
#  4      kJzGH0PVQHQ  why Samantha became EMOTIONAL @ Samantha naga ...
#  ...            ...                                                ...
#  37347  iNHecA3PJCo  फेकू आशिक़ - राजस्थान की सबसे शानदार कॉमेडी | ...
#  37348  dpPmPbhcslM                         Seetha | Flowers | Ep# 364
#  37349  mV6aztP58f8  Bhramanam I Episode 87 - 12 June 2018 I Mazhav...
#  37350  qxqDNP1bDEw  Nua Bohu | Full Ep 285 | 13th June 2018 | Odia...
#  37351  wERgpPK44w0  Ee Nagaraniki Emaindi Trailer | Tharun Bhascke...
#
#         views_tIN  comment_count_tIN trending_date_tIN country_code_tIN
#  0        1096327                882          17.14.11               IN
#  1         590101                  0          17.14.11               IN
#  2         473988                149          17.14.11               IN
#  3        1242680               2684          17.14.11               IN
#  4         464015                 66          17.14.11               IN
#  ...          ...                ...               ...              ...
#  37347     214378                196          18.14.06               IN
#  37348     406828               1428          18.14.06               IN
#  37349     386319                697          18.14.06               IN
#  37350     130263                 65          18.14.06               IN
#  37351    1278249               1205          18.14.06               IN
#
#  [37352 rows x 6 columns],
#  'dfJP':       video_id_tJP                                          title_tJP  \
#  0      5ugKfHgsmYw                                 陸自ヘリ、垂直に落下＝路上の車が撮影
#  1      ohObafdd34Y                             イッテQ お祭り男宮川×手越 巨大ブランコ②
#  2      aBr2kKAHN6M                              Live Views of Starman
#  3      5wNnwChvmsQ                         東京ディズニーリゾートの元キャストが暴露した秘密5選
#  4      B7J47qFvdsk          榮倉奈々、衝撃の死んだふり！映画『家に帰ると妻が必ず死んだふりをしています。』特報
#  ...            ...                                                ...
#  20518  GuWCkLnCMOo  หนึ่งด้าวฟ้าเดียว NeungDaoFahDeaw EP.15 ตอนที่...
#  20519  nOUlB0i2MaA  2018 국민의 선택 - 선거방송 '왕의 귀환' 12시간 연속 생중계! (풀영상) ...
#  20520  4cRanIowkTE            元FBIエージェントが教える、200％人を引き付けるようになるコツ、トップ10
#  20521  oLtWIVBVoS8     日本×パラグアイ徹底分析&スペイン代表監督解任事件を解説【トークtheフットボール】#683
#  20522  2IEWv23oa9E                             エサのコオロギに夢中で二本足で立つカメレオン
#
#         views_tJP  comment_count_tJP trending_date_tJP country_code_tJP
#  0         188085                  0          18.07.02               JP
#  1          90929                174          18.07.02               JP
#  2        6408303               3006          18.07.02               JP
#  3          96255                545          18.07.02               JP
#  4         108408                201          18.07.02               JP
#  ...          ...                ...               ...              ...
#  20518      81321                 61          18.14.06               JP
#  20519     433188                175          18.14.06               JP
#  20520      39235                 46          18.14.06               JP
#  20521      49900                336          18.14.06               JP
#  20522      46265                 59          18.14.06               JP
#
#  [20523 rows x 6 columns],
#  'dfKR':       video_id_tKR                              title_tKR  views_tKR  \
#  0      RxGQe4EeEpA                     좋아 by 민서_윤종신_좋니 답가     156130
#  1      hH7wVE8OlQ0                       JSA 귀순 북한군 총격 부상      76533
#  2      9V8bnWUmE9U             나몰라패밀리 운동화 영상 2탄 (빼빼로데이버젼)     421409
#  3      0_8py-t5R80             이명박 출국 현장, 놓치면 안되는 장면     222850
#  4      bk55RbxiQdI                김장겸은 물러갔다 MBC 노조 환호와 눈물      84466
#  ...            ...                                    ...        ...
#  34562  pj6YBBrO1sQ             장모님 가게한다고 1억만 달라는 아내 사이다카톡     156439
#  34563  _Ne9ER-jr20        여러분~ 렌즈가 이렇게 위험합니다!!!ㅜㅜ _[이슈텔러]     130948
#  34564  xuOQq_fzEjk                     2018년 6월 13일 아침 뉴스      62555
#  34565  uXvjxeg08eQ          워너원 웃음 참기 영상 워너원 GO X-con.ver      63306
#  34566  C-bLqIftDY4  [법륜스님의 즉문즉설 제 1398회] 시동생의 아이를 키우게 됐어요      63716
#
#         comment_count_tKR trending_date_tKR country_code_tKR
#  0                    272          17.14.11               KR
#  1                    113          17.14.11               KR
#  2                    459          17.14.11               KR
#  3                   1219          17.14.11               KR
#  4                    450          17.14.11               KR
#  ...                  ...               ...              ...
#  34562                308          18.14.06               KR
#  34563                988          18.14.06               KR
#  34564                105          18.14.06               KR
#  34565                571          18.14.06               KR
#  34566                135          18.14.06               KR
#
#  [34567 rows x 6 columns],
#  'dfMX':       video_id_tMX                                          title_tMX  \
#  0      SbOwzAl9ZfQ                      Capítulo 12 | MasterChef 2017
#  1      klOV6Xh-DnI  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
#  2      6L2ZF7Qzsbk             LOUIS CKAGÓ - EL PULSO DE LA REPÚBLICA
#  3      hcY52MFWMDM   Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
#  4      _OXDcGPVAa4           DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
#  ...            ...                                                ...
#  40446  r63VBOagGAo  Shawn Mendes x Portugal (FPF Official World Cu...
#  40447  i7r_kMbyngk  AMLO llegó con su esposa al Tercer Debate en M...
#  40448  _jnwjdMe3Zo  Maire usa una blusa kawaiii ¿adorable o ridícula?
#  40449  pAH9omNAWA4         La Jefa del Campeón - Capítulo 2 Parte 3/4
#  40450  dj5Z4jTE3-c  ¿POR QUÉ SHANKS ES TAN RESPETADO POR TODOS EN ...
#
#         views_tMX  comment_count_tMX trending_date_tMX country_code_tMX
#  0         310130               1836          17.14.11               MX
#  1         104972                369          17.14.11               MX
#  2         136064                607          17.14.11               MX
#  3          96153                208          17.14.11               MX
#  4         499965               7428          17.14.11               MX
#  ...          ...                ...               ...              ...
#  40446     653114               3826          18.14.06               MX
#  40447     121674                491          18.14.06               MX
#  40448      14067                 90          18.14.06               MX
#  40449      22898                  3          18.14.06               MX
#  40450     108936                993          18.14.06               MX
#
#  [40451 rows x 6 columns],
#  'dfRU':       video_id_tRU                                          title_tRU  \
#  0      gDuslQ9avLc                    Захар и Полина учатся экономить
#  1      AOCJIFEA_jE                   Биржа Мемов #29. Большой выпуск
#  2      VAWNQDgwwOM                       ХАЙП КЭМП - СВОЙ СРЕДИ ЧУЖИХ
#  3      gknkFwKQfHg                         Сочная кесадилья с курицей
#  4      3sYvZcwzZr8              КЛИПЫ РОДИТЕЛЕЙ НА ШКОЛЬНЫЙ ВЫПУСКНОЙ
#  ...            ...                                                ...
#  40734  OMmR9THjVKM  У меня СДВГ! (Story booth на русском) Русская ...
#  40735  tX7p7NtNVDE                    Мои Детские Травмы 2 (анимация)
#  40736  KAyj5Xm1C64  [ENG SUB] BTS PROM PARTY 2018 Intro + 2nd Gran...
#  40737  4PiSLIrsSiY  ОБЗОР ВАННОЙ КОМНАТЫ🛁/ТУАЛЕТНОЙ КОМНАТЫ🚽 + ДЕК...
#  40738  Ehy5foVfKOE                    Плохой сигнал. Стань человеком!
#
#         views_tRU  comment_count_tRU trending_date_tRU country_code_tRU
#  0          62408                 50          17.14.11               RU
#  1         330043               2977          17.14.11               RU
#  2         424596               2944          17.14.11               RU
#  3         112851                 80          17.14.11               RU
#  4         243469               1692          17.14.11               RU
#  ...          ...                ...               ...              ...
#  40734     129488                990          18.14.06               RU
#  40735      99163                692          18.14.06               RU
#  40736     449611                974          18.14.06               RU
#  40737      14225                209          18.14.06               RU
#  40738      52340               1819          18.14.06               RU
#
#  [40739 rows x 6 columns],
#  'dfUS':       video_id_tUS                                          title_tUS  \
#  0      2kyS6SvSYSE                 WE WANT TO TALK ABOUT OUR MARRIAGE
#  1      1ZAPwfrtAFY  The Trump Presidency: Last Week Tonight with J...
#  2      5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...
#  3      puqaWrEC7tY                   Nickelback Lyrics: Real or Fake?
#  4      d380meD0W0M                           I Dare You: GOING BALD!?
#  ...            ...                                                ...
#  40944  BZt0qjTWNhw                       The Cat Who Caught the Laser
#  40945  1h7KV2sjUWY                         True Facts : Ant Mutualism
#  40946  D6Oy4LfoqsU  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
#  40947  oV0zkMe1K8s                How Black Panther Should Have Ended
#  40948  ooyjaVdt-jA  Official Call of Duty®: Black Ops 4 — Multipla...
#
#         views_tUS  comment_count_tUS trending_date_tUS country_code_tUS
#  0         748374              15954          17.14.11               US
#  1        2418783              12703          17.14.11               US
#  2        3191434               8181          17.14.11               US
#  3         343168               2146          17.14.11               US
#  4        2095731              17518          17.14.11               US
#  ...          ...                ...               ...              ...
#  40944    1685609               2657          18.14.06               US
#  40945    1064798               3936          18.14.06               US
#  40946    1066451               3992          18.14.06               US
#  40947    5660813              13088          18.14.06               US
#  40948   10306119             144795          18.14.06               US
#
#  [40949 rows x 6 columns]}

# %% [markdown]
# ### Create countries File

# %%
country_names = ["Canada", "Germany", "France", "United Kingdom", "India", "Japan", "Korea", "Mexico", "Russia", "United States"]

country_df = pd.DataFrame(list(zip(countries, country_names)), columns=['country_code', 'country_name'])

output_path = os.path.join("Data", "countries.csv")
country_df.to_csv(output_path, index=False)

# %% [markdown]
# ### Create video File

# %%
id = []
vid_title = []

for row in video_countries_df:
    if row['video_id'] not in video_id:
        id.append(row['video_id'])
        vid_title.append(row['title'])
